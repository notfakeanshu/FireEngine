# %%
import pandas as pd
movies=  pd.read_csv('movies.csv')
credits = pd.read_csv('credits.csv')
val = movies['original_language'].unique().tolist()
val
# Out:
# ['en',
#  'ja',
#  'fr',
#  'zh',
#  'es',
#  'de',
#  'hi',
#  'ru',
#  'ko',
#  'te',
#  'cn',
#  'it',
#  'nl',
#  'ta',
#  'sv',
#  'th',
#  'da',
#  'xx',
#  'hu',
#  'cs',
#  'pt',
#  'is',
#  'tr',
#  'nb',
#  'af',
#  'pl',
#  'he',
#  'ar',
#  'vi',
#  'ky',
#  'id',
#  'ro',
#  'fa',
#  'no',
#  'sl',
#  'ps',
#  'el']

# %%
movies = movies.merge(credits,on='title')

# %%
movies  = movies[['genres','id','keywords','title','overview','cast','crew']]

# %%
movies = movies.dropna()
movies['genres'][0]
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
import ast
def convertGenre(obj):
    list = []
    l2 = ast.literal_eval(obj)
    for i in l2:
        list.append(i['name'])
    return list

movies.loc[:,'genres'] = movies['genres'].apply(convertGenre)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4806 entries, 0 to 4808
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   genres    4806 non-null   object
#  1   id        4806 non-null   int64
#  2   keywords  4806 non-null   object
#  3   title     4806 non-null   object
#  4   overview  4806 non-null   object
#  5   cast      4806 non-null   object
#  6   crew      4806 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 429.4+ KB

# %%
movies.loc[:,'keywords'] = movies['keywords'].apply(convertGenre)

# %%
movies
# Out:
#                                              genres      id  \
# 0     [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                      [Adventure, Fantasy, Action]     285
# 2                        [Action, Adventure, Crime]  206647
# 3                  [Action, Crime, Drama, Thriller]   49026
# 4              [Action, Adventure, Science Fiction]   49529
# ...                                             ...     ...
# 4804                      [Action, Crime, Thriller]    9367
# 4805                              [Comedy, Romance]   72766
# 4806             [Comedy, Drama, Romance, TV Movie]  231617
# 4807                                             []  126186
# 4808                                  [Documentary]   25975
#
#                                                keywords  \
# 0     [culture clash, future, space war, space colon...
# 1     [ocean, drug abuse, exotic island, east india ...
# 2     [spy, based on novel, secret agent, sequel, mi...
# 3     [dc comics, crime fighter, terrorist, secret i...
# 4     [based on novel, mars, medallion, space travel...
# ...                                                 ...
# 4804  [united states–mexico barrier, legs, arms, pap...
# 4805                                                 []
# 4806  [date, love at first sight, narration, investi...
# 4807                                                 []
# 4808          [obsession, camcorder, crush, dream girl]
#
#                                          title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4804                               El Mariachi
# 4805                                 Newlyweds
# 4806                 Signed, Sealed, Delivered
# 4807                          Shanghai Calling
# 4808                         My Date with Drew
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 4804  El Mariachi just wants to play his guitar and ...
# 4805  A newlywed couple's honeymoon is upended by th...
# 4806  "Signed, Sealed, Delivered" introduces a dedic...
# 4807  When ambitious New York attorney Sam is sent t...
# 4808  Ever since the second grade when he first saw ...
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# 3     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4     [{"cast_id": 5, "character": "John Carter", "c...
# ...                                                 ...
# 4804  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4805  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4806  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4807  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4808  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...                                                 ...
# 4804  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4805  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4806  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4807  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4808  [{"credit_id": "58ce021b9251415a390165d9", "de...
#
# [4806 rows x 7 columns]

# %%
def convertCast(obj):
    list=  []
    ctr= 0
    l2 = ast.literal_eval(obj)
    for i in l2:
        list.append(i['name'])
        ctr+=1
        if(ctr==3):
            break
    return list

# %%
movies.loc[:,'cast'] = movies['cast'].apply(convertCast)

# %%
movies
# Out:
#                                              genres      id  \
# 0     [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                      [Adventure, Fantasy, Action]     285
# 2                        [Action, Adventure, Crime]  206647
# 3                  [Action, Crime, Drama, Thriller]   49026
# 4              [Action, Adventure, Science Fiction]   49529
# ...                                             ...     ...
# 4804                      [Action, Crime, Thriller]    9367
# 4805                              [Comedy, Romance]   72766
# 4806             [Comedy, Drama, Romance, TV Movie]  231617
# 4807                                             []  126186
# 4808                                  [Documentary]   25975
#
#                                                keywords  \
# 0     [culture clash, future, space war, space colon...
# 1     [ocean, drug abuse, exotic island, east india ...
# 2     [spy, based on novel, secret agent, sequel, mi...
# 3     [dc comics, crime fighter, terrorist, secret i...
# 4     [based on novel, mars, medallion, space travel...
# ...                                                 ...
# 4804  [united states–mexico barrier, legs, arms, pap...
# 4805                                                 []
# 4806  [date, love at first sight, narration, investi...
# 4807                                                 []
# 4808          [obsession, camcorder, crush, dream girl]
#
#                                          title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4804                               El Mariachi
# 4805                                 Newlyweds
# 4806                 Signed, Sealed, Delivered
# 4807                          Shanghai Calling
# 4808                         My Date with Drew
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 4804  El Mariachi just wants to play his guitar and ...
# 4805  A newlywed couple's honeymoon is upended by th...
# 4806  "Signed, Sealed, Delivered" introduces a dedic...
# 4807  When ambitious New York attorney Sam is sent t...
# 4808  Ever since the second grade when he first saw ...
#
#                                                    cast  \
# 0      [Sam Worthington, Zoe Saldana, Sigourney Weaver]
# 1         [Johnny Depp, Orlando Bloom, Keira Knightley]
# 2          [Daniel Craig, Christoph Waltz, Léa Seydoux]
# 3          [Christian Bale, Michael Caine, Gary Oldman]
# 4        [Taylor Kitsch, Lynn Collins, Samantha Morton]
# ...                                                 ...
# 4804  [Carlos Gallardo, Jaime de Hoyos, Peter Marqua...
# 4805       [Edward Burns, Kerry Bishé, Marsha Dietlein]
# 4806         [Eric Mabius, Kristin Booth, Crystal Lowe]
# 4807          [Daniel Henney, Eliza Coupe, Bill Paxton]
# 4808  [Drew Barrymore, Brian Herzlinger, Corey Feldman]
#
#                                                    crew
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...                                                 ...
# 4804  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4805  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4806  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4807  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4808  [{"credit_id": "58ce021b9251415a390165d9", "de...
#
# [4806 rows x 7 columns]

# %%
def get_Director(obj):
    l2=  ast.literal_eval(obj)
    l = []
    for i in l2:
        if(i['job']=='Director'):
            l.append(i['name'])
            break
    return l
movies.loc[:,'crew'] = movies['crew'].apply(get_Director)

# %%
movies.loc[:,'overview'] = movies['overview'].apply(lambda x:x.split())
def removeSpace(lst):
    return [i.replace(" ", "") for i in lst]

movies.loc[:,'genres'] = movies['genres'].apply(removeSpace)
movies.loc[:,'keywords'] = movies['keywords'].apply(removeSpace)
movies.loc[:,'cast'] = movies['cast'].apply(removeSpace)
movies.loc[:,'crew'] = movies['crew'].apply(removeSpace)

# %%
movies.sample(100)
# Out:
#                                                  genres      id  \
# 3203                                   [Drama, Romance]   41248
# 3787                                   [Drama, Fantasy]  103328
# 3708                          [Drama, Foreign, Romance]   65749
# 4596                                  [Drama, Thriller]  157909
# 1120                            [Action, Comedy, Crime]   64688
# ...                                                 ...     ...
# 3213                                   [Horror, Comedy]    1547
# 1604                                        [Adventure]    9266
# 450                    [Comedy, Family, ScienceFiction]    9574
# 158                 [ScienceFiction, Action, Adventure]   13475
# 782   [Action, Comedy, Thriller, Crime, ScienceFiction]    8285
#
#                                                keywords  \
# 3203                                                 []
# 3787  [limousine, multipleidentities, wig, penis, ta...
# 3708                     [dancer, tango, musical, love]
# 4596                                       [kidnapping]
# 1120  [malefriendship, highschool, parody, crudehumo...
# ...                                                 ...
# 3213  [streetgang, smalltown, vampire, comicbook, bo...
# 1604  [sea, surfer, hawaii, sport, job, americanfoot...
# 450   [weddingvows, inventor, slime, green, flight, ...
# 158   [spacecraft, teleportation, spacemission, para...
# 782   [secretidentity, robber, mask, frog, basedonco...
#
#                       title  \
# 3203  The Girl on the Train
# 3787            Holy Motors
# 3708                  Tango
# 4596                Show Me
# 1120         21 Jump Street
# ...                     ...
# 3213          The Lost Boys
# 1604             Blue Crush
# 450                 Flubber
# 158               Star Trek
# 782              The Spirit
#
#                                                overview  \
# 3203  [The, Girl, on, the, Train, is, a, 2009, Frenc...
# 3787  [We, follow, 24, hours, in, the, life, of, a, ...
# 3708  [A, dangerous, love, affair, inspires, a, dire...
# 4596  [When, two, squeegee, kids, descend, upon, Sar...
# 1120  [In, high, school,, Schmidt, was, a, dork, and...
# ...                                                 ...
# 3213  [A, mother, and, her, two, teenage, sons, move...
# 1604  [Nothing, gets, between, Anne, Marie, and, her...
# 450   [Professor, Phillip, Brainard,, an, absent, mi...
# 158   [The, fate, of, the, galaxy, rests, in, the, h...
# 782   [Down, these, mean, streets, a, man, must, com...
#
#                                                    cast                 crew
# 3203    [MichelBlanc, CatherineDeneuve, ÉmilieDequenne]       [AndréTéchiné]
# 3787           [EvaMendes, KylieMinogue, MichelPiccoli]          [LeosCarax]
# 3708       [MiguelÁngelSolá, CeciliaNarova, MíaMaestro]        [CarlosSaura]
# 4596    [MichelleNolden, KatharineIsabelle, KettTurton]  [CassandraNicolaou]
# 1120             [ChanningTatum, JonahHill, BrieLarson]           [PhilLord]
# ...                                                 ...                  ...
# 3213             [JasonPatric, CoreyHaim, CoreyFeldman]     [JoelSchumacher]
# 1604    [KateBosworth, MatthewDavis, MichelleRodriguez]      [JohnStockwell]
# 450   [RobinWilliams, MarciaGayHarden, ChristopherMc...        [LesMayfield]
# 158            [ChrisPine, ZacharyQuinto, LeonardNimoy]         [J.J.Abrams]
# 782   [GabrielMacht, ScarlettJohansson, SamuelL.Jack...        [FrankMiller]
#
# [100 rows x 7 columns]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4806 entries, 0 to 4808
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   genres    4806 non-null   object
#  1   id        4806 non-null   int64
#  2   keywords  4806 non-null   object
#  3   title     4806 non-null   object
#  4   overview  4806 non-null   object
#  5   cast      4806 non-null   object
#  6   crew      4806 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 429.4+ KB

# %%
genre_to_mood = {
    "Action": "Excited",
    "Adventure": "Excited",
    "Animation": "Happy",
    "Comedy": "Happy",
    "Crime": "Thrilled",
    "Documentary": "Calm",
    "Drama": "Emotional",
    "Family": "Happy",
    "Fantasy": "Curious",
    "Foreign": "Curious",
    "History": "Curious",
    "Horror": "Thrilled",
    "Music": "Happy",
    "Mystery": "Curious",
    "Romance": "Romantic",
    "ScienceFiction": "Curious",
    "TVMovie": "Happy",
    "Thriller": "Thrilled",
    "War": "Emotional",
    "Western": "Excited"
}

# %%
def mood_from_genres(genres):
    for genre in genres:
        mood = genre_to_mood.get(genre)
        if mood:
            return mood
    return "Curious"  # default if no matching genre




# Apply mood tag to each row
movies['mood_tag'] = movies['genres'].apply(mood_from_genres)

# %%
movies.sample(10)
# Out:
#                                           genres      id  \
# 3931                   [Drama, History, Romance]   28005
# 2934                     [Action, Comedy, Crime]   17708
# 2921               [Action, Comedy, Documentary]   12094
# 3430                  [ScienceFiction, Thriller]   10514
# 4121                            [Comedy, Horror]   13121
# 369       [Action, Adventure, Fantasy, Thriller]    1996
# 1880  [Adventure, Fantasy, Drama, Comedy, Music]    6116
# 3082                                    [Comedy]   67911
# 875                      [Drama, Music, Romance]     824
# 2018                                [War, Drama]  256917
#
#                                                keywords  \
# 3931                 [poetry, eroticism, womandirector]
# 2934                                                 []
# 2921  [wound, disgust, pain, stunts, stuntman, stupi...
# 3430  [nasa, newmexico, biologicalweapon, epilepsy, ...
# 4121                                                 []
# 369   [riddle, treasure, medallion, kenia, alexander...
# 1880                         [pop, popculture, popstar]
# 3082                             [pornostar, hollywood]
# 875   [duke, musical, writer'sblock, music, terminal...
# 2018  [istanbul, australia, postworldwari, farmer, m...
#
#                                            title  \
# 3931                 Kama Sutra - A Tale of Love
# 2934                                Corky Romano
# 2921                          Jackass Number Two
# 3430                        The Andromeda Strain
# 4121                                       Teeth
# 369   Lara Croft Tomb Raider: The Cradle of Life
# 1880                                 Spice World
# 3082             Bucky Larson: Born to Be a Star
# 875                                Moulin Rouge!
# 2018                           The Water Diviner
#
#                                                overview  \
# 3931  [Tara, and, Maya, are, two, inseparable, frien...
# 2934  [Corky, Romano, is, a, bumbling,, simpleton,, ...
# 2921  [Jackass, Number, Two, is, a, compilation, of,...
# 3430  [When, virtually, all, of, the, residents, of,...
# 4121  [Dawn, is, an, active, member, of, her, high-s...
# 369   [Lara, Croft, ventures, to, an, underwater, te...
# 1880  [The, film, follows, the, Spice, Girls, and, t...
# 3082  [A, kid, from, the, Midwest, moves, out, to, H...
# 875   [A, celebration, of, love, and, creative, insp...
# 2018  [In, 1919,, Australian, farmer, Joshua, Connor...
#
#                                               cast                    crew  \
# 3931  [IndiraVarma, SaritaChoudhury, RamonTikaram]              [MiraNair]
# 2934         [ChrisKattan, VinessaShaw, PeterFalk]             [RobPritts]
# 2921        [JohnnyKnoxville, BamMargera, Steve-O]          [JeffTremaine]
# 3430          [ArthurHill, DavidWayne, JamesOlson]            [RobertWise]
# 4121          [JessWeixler, JohnHensley, JoshPais]  [MitchellLichtenstein]
# 369      [AngelinaJolie, GerardButler, NoahTaylor]             [JandeBont]
# 1880   [VictoriaBeckham, MelanieBrown, EmmaBunton]             [BobSpiers]
# 3082  [NickSwardson, ChristinaRicci, StephenDorff]              [TomBrady]
# 875    [NicoleKidman, EwanMcGregor, JohnLeguizamo]           [BazLuhrmann]
# 2018  [RussellCrowe, OlgaKurylenko, YılmazErdoğan]          [RussellCrowe]
#
#        mood_tag
# 3931  Emotional
# 2934    Excited
# 2921    Excited
# 3430    Curious
# 4121      Happy
# 369     Excited
# 1880    Excited
# 3082      Happy
# 875   Emotional
# 2018  Emotional

# %%
movies['mood_tag'][0]
# Out:
# 'Excited'

# %%
def getMov(genre):
    lst  = []
    for i in range(len(movies)):
        if(movies['mood_tag'].iloc[i]==genre):
            lst.append(movies['title'].iloc[i])
    return lst

# %%
movies['tags'] =  movies['genres'] + movies['keywords']+movies['overview']+movies['cast']+movies['crew']

# %%
movies
# Out:
#                                             genres      id  \
# 0     [Action, Adventure, Fantasy, ScienceFiction]   19995
# 1                     [Adventure, Fantasy, Action]     285
# 2                       [Action, Adventure, Crime]  206647
# 3                 [Action, Crime, Drama, Thriller]   49026
# 4              [Action, Adventure, ScienceFiction]   49529
# ...                                            ...     ...
# 4804                     [Action, Crime, Thriller]    9367
# 4805                             [Comedy, Romance]   72766
# 4806             [Comedy, Drama, Romance, TVMovie]  231617
# 4807                                            []  126186
# 4808                                 [Documentary]   25975
#
#                                                keywords  \
# 0     [cultureclash, future, spacewar, spacecolony, ...
# 1     [ocean, drugabuse, exoticisland, eastindiatrad...
# 2     [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3     [dccomics, crimefighter, terrorist, secretiden...
# 4     [basedonnovel, mars, medallion, spacetravel, p...
# ...                                                 ...
# 4804  [unitedstates–mexicobarrier, legs, arms, paper...
# 4805                                                 []
# 4806  [date, loveatfirstsight, narration, investigat...
# 4807                                                 []
# 4808           [obsession, camcorder, crush, dreamgirl]
#
#                                          title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4804                               El Mariachi
# 4805                                 Newlyweds
# 4806                 Signed, Sealed, Delivered
# 4807                          Shanghai Calling
# 4808                         My Date with Drew
#
#                                                overview  \
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     [Captain, Barbossa,, long, believed, to, be, d...
# 2     [A, cryptic, message, from, Bond’s, past, send...
# 3     [Following, the, death, of, District, Attorney...
# 4     [John, Carter, is, a, war-weary,, former, mili...
# ...                                                 ...
# 4804  [El, Mariachi, just, wants, to, play, his, gui...
# 4805  [A, newlywed, couple's, honeymoon, is, upended...
# 4806  ["Signed,, Sealed,, Delivered", introduces, a,...
# 4807  [When, ambitious, New, York, attorney, Sam, is...
# 4808  [Ever, since, the, second, grade, when, he, fi...
#
#                                                 cast                crew  \
# 0      [SamWorthington, ZoeSaldana, SigourneyWeaver]      [JamesCameron]
# 1         [JohnnyDepp, OrlandoBloom, KeiraKnightley]     [GoreVerbinski]
# 2          [DanielCraig, ChristophWaltz, LéaSeydoux]         [SamMendes]
# 3          [ChristianBale, MichaelCaine, GaryOldman]  [ChristopherNolan]
# 4        [TaylorKitsch, LynnCollins, SamanthaMorton]     [AndrewStanton]
# ...                                              ...                 ...
# 4804  [CarlosGallardo, JaimedeHoyos, PeterMarquardt]   [RobertRodriguez]
# 4805       [EdwardBurns, KerryBishé, MarshaDietlein]       [EdwardBurns]
# 4806         [EricMabius, KristinBooth, CrystalLowe]        [ScottSmith]
# 4807          [DanielHenney, ElizaCoupe, BillPaxton]        [DanielHsia]
# 4808  [DrewBarrymore, BrianHerzlinger, CoreyFeldman]   [BrianHerzlinger]
#
#      mood_tag                                               tags
# 0     Excited  [Action, Adventure, Fantasy, ScienceFiction, c...
# 1     Excited  [Adventure, Fantasy, Action, ocean, drugabuse,...
# 2     Excited  [Action, Adventure, Crime, spy, basedonnovel, ...
# 3     Excited  [Action, Crime, Drama, Thriller, dccomics, cri...
# 4     Excited  [Action, Adventure, ScienceFiction, basedonnov...
# ...       ...                                                ...
# 4804  Excited  [Action, Crime, Thriller, unitedstates–mexicob...
# 4805    Happy  [Comedy, Romance, A, newlywed, couple's, honey...
# 4806    Happy  [Comedy, Drama, Romance, TVMovie, date, loveat...
# 4807  Curious  [When, ambitious, New, York, attorney, Sam, is...
# 4808     Calm  [Documentary, obsession, camcorder, crush, dre...
#
# [4806 rows x 9 columns]

# %%
df = movies[['id','title','mood_tag','tags']]

# %%
df
# Out:
#           id                                     title mood_tag  \
# 0      19995                                    Avatar  Excited
# 1        285  Pirates of the Caribbean: At World's End  Excited
# 2     206647                                   Spectre  Excited
# 3      49026                     The Dark Knight Rises  Excited
# 4      49529                               John Carter  Excited
# ...      ...                                       ...      ...
# 4804    9367                               El Mariachi  Excited
# 4805   72766                                 Newlyweds    Happy
# 4806  231617                 Signed, Sealed, Delivered    Happy
# 4807  126186                          Shanghai Calling  Curious
# 4808   25975                         My Date with Drew     Calm
#
#                                                    tags
# 0     [Action, Adventure, Fantasy, ScienceFiction, c...
# 1     [Adventure, Fantasy, Action, ocean, drugabuse,...
# 2     [Action, Adventure, Crime, spy, basedonnovel, ...
# 3     [Action, Crime, Drama, Thriller, dccomics, cri...
# 4     [Action, Adventure, ScienceFiction, basedonnov...
# ...                                                 ...
# 4804  [Action, Crime, Thriller, unitedstates–mexicob...
# 4805  [Comedy, Romance, A, newlywed, couple's, honey...
# 4806  [Comedy, Drama, Romance, TVMovie, date, loveat...
# 4807  [When, ambitious, New, York, attorney, Sam, is...
# 4808  [Documentary, obsession, camcorder, crush, dre...
#
# [4806 rows x 4 columns]

# %%
df.loc[:,'tags'] = df['tags'].apply(lambda x:" ".join(x))

# %%
df
# Out:
#           id                                     title mood_tag  \
# 0      19995                                    Avatar  Excited
# 1        285  Pirates of the Caribbean: At World's End  Excited
# 2     206647                                   Spectre  Excited
# 3      49026                     The Dark Knight Rises  Excited
# 4      49529                               John Carter  Excited
# ...      ...                                       ...      ...
# 4804    9367                               El Mariachi  Excited
# 4805   72766                                 Newlyweds    Happy
# 4806  231617                 Signed, Sealed, Delivered    Happy
# 4807  126186                          Shanghai Calling  Curious
# 4808   25975                         My Date with Drew     Calm
#
#                                                    tags
# 0     Action Adventure Fantasy ScienceFiction cultur...
# 1     Adventure Fantasy Action ocean drugabuse exoti...
# 2     Action Adventure Crime spy basedonnovel secret...
# 3     Action Crime Drama Thriller dccomics crimefigh...
# 4     Action Adventure ScienceFiction basedonnovel m...
# ...                                                 ...
# 4804  Action Crime Thriller unitedstates–mexicobarri...
# 4805  Comedy Romance A newlywed couple's honeymoon i...
# 4806  Comedy Drama Romance TVMovie date loveatfirsts...
# 4807  When ambitious New York attorney Sam is sent t...
# 4808  Documentary obsession camcorder crush dreamgir...
#
# [4806 rows x 4 columns]

# %%
df['tags'][0]
# Out:
# 'Action Adventure Fantasy ScienceFiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization. SamWorthington ZoeSaldana SigourneyWeaver JamesCameron'

# %%
import nltk
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
# Out:
# 'fuck'

# %%
def convertStem(obj):
    lst = obj.split()
    ans=  []
    for i in lst:
        ans.append(ps.stem(i))
    return " ".join(ans)

# %%
df.loc[:,'tags'] = df['tags'].apply(convertStem)

# %%
df
# Out:
#           id                                     title mood_tag  \
# 0      19995                                    Avatar  Excited
# 1        285  Pirates of the Caribbean: At World's End  Excited
# 2     206647                                   Spectre  Excited
# 3      49026                     The Dark Knight Rises  Excited
# 4      49529                               John Carter  Excited
# ...      ...                                       ...      ...
# 4804    9367                               El Mariachi  Excited
# 4805   72766                                 Newlyweds    Happy
# 4806  231617                 Signed, Sealed, Delivered    Happy
# 4807  126186                          Shanghai Calling  Curious
# 4808   25975                         My Date with Drew     Calm
#
#                                                    tags
# 0     action adventur fantasi sciencefict culturecla...
# 1     adventur fantasi action ocean drugabus exotici...
# 2     action adventur crime spi basedonnovel secreta...
# 3     action crime drama thriller dccomic crimefight...
# 4     action adventur sciencefict basedonnovel mar m...
# ...                                                 ...
# 4804  action crime thriller unitedstates–mexicobarri...
# 4805  comedi romanc a newlyw couple' honeymoon is up...
# 4806  comedi drama romanc tvmovi date loveatfirstsig...
# 4807  when ambiti new york attorney sam is sent to s...
# 4808  documentari obsess camcord crush dreamgirl eve...
#
# [4806 rows x 4 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')
cv.fit(df['tags'])
# Out:
# CountVectorizer(max_features=5000, stop_words='english')

# %%
vectors = cv.transform(df['tags']).toarray()

# %%
from sklearn.metrics.pairwise import cosine_similarity
similar_movies = cosine_similarity(vectors)

# %%
#map for movies
movies_map = { title: idx for idx, title in enumerate(df['title']) }

# %%
def getMovies(movie):
    index = movies_map[movie]
    list_movies=  sorted(list(enumerate(similar_movies[index])),reverse=True,key=lambda x:x[1])[1:6]
    return list_movies

# %%
def getName(movie):
    lst = getMovies(movie)
    for i in lst:
        print(df.loc[i[0]].title)

# %%
getName('The Avengers')
# Out:
# Iron Man 3
# Avengers: Age of Ultron
# Captain America: Civil War
# Captain America: The First Avenger
# Iron Man

# %%
similar_movies.shape
# Out:
# (4806, 4806)

# %% [markdown]
# # Sample Data

# %%
user_history = [
    ['The Dark Knight Rises','Avatar','Iron Man'],              #Every Movie
    ['Avatar','Iron Man','Jurassic World'],                     #Excited
    ['Cars 2','Meet the Fockers','Ted 2'],                      #Happy
    ['Now You See Me','The Conjuring 2','Final Destination 5'], #thrilled
    ['The Square','Ayurveda: Art of Being','Super Size Me'],    #Calm
    ['Titanic','The Martian','Unbroken'],                       #Emotional
    ['Gravity','The Time Machine','The Last Days on Mars'],     #Curious 
    ['Titanic','Friends with Benefits','To Rome with Love'],    #Romantic
]

# %% [markdown]
# # Recommendation

# %%
# function to get 10 recommended movies based on the last seen 3 movies 
def getRecommendation(recent_watched):
    top3 = recent_watched[-3:]
    movie_indices = [movies_map[i] for i in top3]
    
    recommended = []
    
    for idx in movie_indices:
        sim_scores = list(enumerate(similar_movies[idx]))
        sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)[1:20]
        recommended.extend(sim_scores)

    recommended = sorted(recommended, key=lambda x: x[1], reverse=True)
    
    seen = set()
    final_recs = []
    for idx, score in recommended:
        if idx not in seen and df.iloc[idx]['title'] not in top3:
            final_recs.append(df.iloc[idx]['title'])
            seen.add(idx)
        if len(final_recs) == 10:
            break
    
    print(final_recs)

# %%
getRecommendation(user_history[5])
# Out:
# ['Fort McCoy', 'Red Tails', 'Letters from Iwo Jima', 'Enemy at the Gates', 'Inchon', 'The Great Raid', 'Black Book', 'Windtalkers', 'Catch-22', 'Saints and Soldiers']

# %% [markdown]
# # Moods

# %%
def getMov(genre):
    lst  = []
    for i in range(len(movies)):
        if(movies['mood_tag'].iloc[i]==genre):
            lst.append(movies['title'].iloc[i])
    return lst

# %%
getMov('Romantic')
# Out:
# ['The Princess and the Frog',
#  'Cinderella',
#  'Cinderella Man',
#  'Just Go with It',
#  'Déjà Vu',
#  "Fool's Gold",
#  'Entrapment',
#  'Focus',
#  'Two Weeks Notice',
#  'Duplicity',
#  'The Break-Up',
#  'The Book of Life',
#  'Out of Sight',
#  'Monster-in-Law',
#  'Kicking & Screaming',
#  'The Sweetest Thing',
#  'Notting Hill',
#  'Dracula',
#  'Julie & Julia',
#  'The Lake House',
#  'Against the Ropes',
#  "What to Expect When You're Expecting",
#  'Friends with Benefits',
#  'I Dreamed of Africa',
#  'The Notebook',
#  'Message in a Bottle',
#  'Corpse Bride',
#  'The Next Three Days',
#  'Grace of Monaco',
#  'Safe Haven',
#  'Pride and Prejudice and Zombies',
#  'Shakespeare in Love',
#  'Accidental Love',
#  'The House Bunny',
#  'Don Juan DeMarco',
#  'Ironclad',
#  'Return to Me',
#  "I Don't Know How She Does It",
#  'The Bridge of San Luis Rey',
#  'Her',
#  "There's Something About Mary",
#  'Joyeux Noël',
#  'Moliere',
#  'To Rome with Love',
#  'Moonlight Mile',
#  'Quigley Down Under',
#  "My Best Friend's Girl",
#  'Leap Year',
#  'The Mask',
#  'My Big Fat Greek Wedding 2',
#  'Honey',
#  'The Wraith',
#  'Soul Plane',
#  'Here On Earth',
#  'Groundhog Day',
#  'Pretty Woman',
#  'Little Children',
#  'Flipped',
#  'The Widow of Saint-Pierre',
#  'Womb',
#  'The Fault in Our Stars',
#  'The Postman Always Rings Twice',
#  "What's Eating Gilbert Grape",
#  'In the Land of Women',
#  'The Ultimate Gift',
#  'The DUFF',
#  'Yeh Jawaani Hai Deewani',
#  'Fido',
#  'Beyond the Lights',
#  'Outside Providence',
#  'Freeheld',
#  'Pale Rider',
#  'A Home at the End of the World',
#  'Mallrats',
#  'Grease',
#  'Emma',
#  'Don Jon',
#  'Fifty Shades of Black',
#  'Fascination',
#  'Christmas Eve',
#  'The Blue Lagoon',
#  'The Crying Game',
#  'The Front Page',
#  'The Perfect Wave',
#  'Dreaming of Joseph Lees',
#  'Slow West',
#  'Before Midnight',
#  'Griff the Invisible',
#  "There's Always Woodstock",
#  'Shortbus',
#  'Dil Jo Bhi Kahey...',
#  "Buffalo '66",
#  'Me You and Five Bucks',
#  'Speedway Junky',
#  'Hidden Away',
#  'Hurricane Streets',
#  'Drinking Buddies',
#  'Fight to the Finish',
#  'As It Is in Heaven',
#  'My Beautiful Laundrette',
#  "Anderson's Cross",
#  'Along the Roadside',
#  'Urbania',
#  'Three',
#  '20 Dates',
#  'Tiny Furniture']
