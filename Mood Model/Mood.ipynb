# %%
import pandas as pd
movies=  pd.read_csv('movies.csv')
credits = pd.read_csv('credits.csv')

# %%
movies = movies.merge(credits,on='title')

# %%
movies  = movies[['genres','id','keywords','title','overview','cast','crew']]

# %%
movies = movies.dropna()
movies['genres'][0]
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
import ast
def convertGenre(obj):
    list = []
    l2 = ast.literal_eval(obj)
    for i in l2:
        list.append(i['name'])
    return list

movies.loc[:,'genres'] = movies['genres'].apply(convertGenre)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4806 entries, 0 to 4808
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   genres    4806 non-null   object
#  1   id        4806 non-null   int64
#  2   keywords  4806 non-null   object
#  3   title     4806 non-null   object
#  4   overview  4806 non-null   object
#  5   cast      4806 non-null   object
#  6   crew      4806 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 429.4+ KB

# %%
movies.loc[:,'keywords'] = movies['keywords'].apply(convertGenre)

# %%
movies
# Out:
#                                              genres      id  \
# 0     [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                      [Adventure, Fantasy, Action]     285
# 2                        [Action, Adventure, Crime]  206647
# 3                  [Action, Crime, Drama, Thriller]   49026
# 4              [Action, Adventure, Science Fiction]   49529
# ...                                             ...     ...
# 4804                      [Action, Crime, Thriller]    9367
# 4805                              [Comedy, Romance]   72766
# 4806             [Comedy, Drama, Romance, TV Movie]  231617
# 4807                                             []  126186
# 4808                                  [Documentary]   25975
#
#                                                keywords  \
# 0     [culture clash, future, space war, space colon...
# 1     [ocean, drug abuse, exotic island, east india ...
# 2     [spy, based on novel, secret agent, sequel, mi...
# 3     [dc comics, crime fighter, terrorist, secret i...
# 4     [based on novel, mars, medallion, space travel...
# ...                                                 ...
# 4804  [united states–mexico barrier, legs, arms, pap...
# 4805                                                 []
# 4806  [date, love at first sight, narration, investi...
# 4807                                                 []
# 4808          [obsession, camcorder, crush, dream girl]
#
#                                          title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4804                               El Mariachi
# 4805                                 Newlyweds
# 4806                 Signed, Sealed, Delivered
# 4807                          Shanghai Calling
# 4808                         My Date with Drew
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 4804  El Mariachi just wants to play his guitar and ...
# 4805  A newlywed couple's honeymoon is upended by th...
# 4806  "Signed, Sealed, Delivered" introduces a dedic...
# 4807  When ambitious New York attorney Sam is sent t...
# 4808  Ever since the second grade when he first saw ...
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# 3     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4     [{"cast_id": 5, "character": "John Carter", "c...
# ...                                                 ...
# 4804  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4805  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4806  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4807  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4808  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...                                                 ...
# 4804  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4805  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4806  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4807  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4808  [{"credit_id": "58ce021b9251415a390165d9", "de...
#
# [4806 rows x 7 columns]

# %%
def convertCast(obj):
    list=  []
    ctr= 0
    l2 = ast.literal_eval(obj)
    for i in l2:
        list.append(i['name'])
        ctr+=1
        if(ctr==3):
            break
    return list

# %%
movies.loc[:,'cast'] = movies['cast'].apply(convertCast)

# %%
movies
# Out:
#                                              genres      id  \
# 0     [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                      [Adventure, Fantasy, Action]     285
# 2                        [Action, Adventure, Crime]  206647
# 3                  [Action, Crime, Drama, Thriller]   49026
# 4              [Action, Adventure, Science Fiction]   49529
# ...                                             ...     ...
# 4804                      [Action, Crime, Thriller]    9367
# 4805                              [Comedy, Romance]   72766
# 4806             [Comedy, Drama, Romance, TV Movie]  231617
# 4807                                             []  126186
# 4808                                  [Documentary]   25975
#
#                                                keywords  \
# 0     [culture clash, future, space war, space colon...
# 1     [ocean, drug abuse, exotic island, east india ...
# 2     [spy, based on novel, secret agent, sequel, mi...
# 3     [dc comics, crime fighter, terrorist, secret i...
# 4     [based on novel, mars, medallion, space travel...
# ...                                                 ...
# 4804  [united states–mexico barrier, legs, arms, pap...
# 4805                                                 []
# 4806  [date, love at first sight, narration, investi...
# 4807                                                 []
# 4808          [obsession, camcorder, crush, dream girl]
#
#                                          title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4804                               El Mariachi
# 4805                                 Newlyweds
# 4806                 Signed, Sealed, Delivered
# 4807                          Shanghai Calling
# 4808                         My Date with Drew
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 4804  El Mariachi just wants to play his guitar and ...
# 4805  A newlywed couple's honeymoon is upended by th...
# 4806  "Signed, Sealed, Delivered" introduces a dedic...
# 4807  When ambitious New York attorney Sam is sent t...
# 4808  Ever since the second grade when he first saw ...
#
#                                                    cast  \
# 0      [Sam Worthington, Zoe Saldana, Sigourney Weaver]
# 1         [Johnny Depp, Orlando Bloom, Keira Knightley]
# 2          [Daniel Craig, Christoph Waltz, Léa Seydoux]
# 3          [Christian Bale, Michael Caine, Gary Oldman]
# 4        [Taylor Kitsch, Lynn Collins, Samantha Morton]
# ...                                                 ...
# 4804  [Carlos Gallardo, Jaime de Hoyos, Peter Marqua...
# 4805       [Edward Burns, Kerry Bishé, Marsha Dietlein]
# 4806         [Eric Mabius, Kristin Booth, Crystal Lowe]
# 4807          [Daniel Henney, Eliza Coupe, Bill Paxton]
# 4808  [Drew Barrymore, Brian Herzlinger, Corey Feldman]
#
#                                                    crew
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...                                                 ...
# 4804  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4805  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4806  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4807  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4808  [{"credit_id": "58ce021b9251415a390165d9", "de...
#
# [4806 rows x 7 columns]

# %%
def get_Director(obj):
    l2=  ast.literal_eval(obj)
    l = []
    for i in l2:
        if(i['job']=='Director'):
            l.append(i['name'])
            break
    return l
movies.loc[:,'crew'] = movies['crew'].apply(get_Director)

# %%
movies.loc[:,'overview'] = movies['overview'].apply(lambda x:x.split())
def removeSpace(lst):
    return [i.replace(" ", "") for i in lst]

movies.loc[:,'genres'] = movies['genres'].apply(removeSpace)
movies.loc[:,'keywords'] = movies['keywords'].apply(removeSpace)
movies.loc[:,'cast'] = movies['cast'].apply(removeSpace)
movies.loc[:,'crew'] = movies['crew'].apply(removeSpace)

# %%
movies.sample(100)
# Out:
#                                              genres      id  \
# 1667                               [Drama, Romance]   11162
# 3672      [Drama, Action, Thriller, ScienceFiction]   11935
# 3857                                        [Drama]  395766
# 3751                                     [Thriller]  241251
# 3380                                [Drama, Family]  104896
# ...                                             ...     ...
# 1464                                        [Drama]   45958
# 3716                              [Drama, Thriller]    4550
# 122   [Adventure, Action, Thriller, ScienceFiction]    2080
# 1635             [ScienceFiction, Action, Thriller]    9920
# 4764                     [Thriller, ScienceFiction]  242095
#
#                                                keywords  \
# 1667  [venice, shakespeare, jew, ship, salesperson, ...
# 3672  [helicopter, nasa, texas, spacecraft, beguilem...
# 3857                                       [miniseries]
# 3751  [malenudity, femalenudity, sex, adultery, infi...
# 3380                                                 []
# ...                                                 ...
# 1464  [immigrant, illegalimmigrant, chinese, singlef...
# 3716                                  [independentfilm]
# 122   [corruption, mutant, boxer, army, marvelcomic,...
# 1635  [skyscraper, vampire, victim, dystopia, boy, d...
# 4764  [hacker, supernaturalpowers, roadtrip, indepen...
#
#                             title  \
# 1667       The Merchant of Venice
# 3672                Capricorn One
# 3857                   The Secret
# 3751            The Boy Next Door
# 3380            A Dog Of Flanders
# ...                           ...
# 1464                     Biutiful
# 3716  Sympathy for Lady Vengeance
# 122      X-Men Origins: Wolverine
# 1635                  Ultraviolet
# 4764                   The Signal
#
#                                                overview  \
# 1667  [In, 16th, century, Venice,, when, a, merchant...
# 3672  [In, order, to, protect, the, reputation, of, ...
# 3857  [The, Secret, is, the, story, of, a, real-life...
# 3751  [A, recently, cheated, on, married, woman, fal...
# 3380  [Poor, but, happy,, young, Nello, and, his, gr...
# ...                                                 ...
# 1464  [This, is, a, story, of, a, man, in, free, fal...
# 3716  [After, a, 13-year, imprisonment, for, the, ki...
# 122   [After, seeking, to, live, a, normal, life,, L...
# 1635  [In, the, late, 21st, century,, a, subculture,...
# 4764  [Three, college, students, on, a, road, trip, ...
#
#                                                  cast  \
# 1667           [AlPacino, JeremyIrons, JosephFiennes]
# 3672       [ElliottGould, JamesBrolin, BrendaVaccaro]
# 3857  [JamesNesbitt, GenevieveO'Reilly, JasonWatkins]
# 3751           [JenniferLopez, RyanGuzman, IanNelson]
# 3380     [JackWarden, JeremyJamesKissner, JesseJames]
# ...                                               ...
# 1464    [JavierBardem, MaricelÁlvarez, HanaaBouchaib]
# 3716        [ChoiMin-sik, LeeYoung-ae, KwonYea-young]
# 122         [HughJackman, LievSchreiber, DannyHuston]
# 1635     [MillaJovovich, CameronBright, NickChinlund]
# 4764        [BrentonThwaites, OliviaCooke, BeauKnapp]
#
#                              crew
# 1667             [MichaelRadford]
# 3672                 [PeterHyams]
# 3857                 [NickMurphy]
# 3751                   [RobCohen]
# 3380                [KevinBrodie]
# ...                           ...
# 1464  [AlejandroGonzálezIñárritu]
# 3716              [ParkChan-wook]
# 122                   [GavinHood]
# 1635                 [KurtWimmer]
# 4764              [WilliamEubank]
#
# [100 rows x 7 columns]

# %%
all_genres = set(genre for sublist in movies['genres'] for genre in sublist)

# %%
all_genres
# Out:
# {'Action',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Foreign',
#  'History',
#  'Horror',
#  'Music',
#  'Mystery',
#  'Romance',
#  'ScienceFiction',
#  'TVMovie',
#  'Thriller',
#  'War',
#  'Western'}

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4806 entries, 0 to 4808
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   genres    4806 non-null   object
#  1   id        4806 non-null   int64
#  2   keywords  4806 non-null   object
#  3   title     4806 non-null   object
#  4   overview  4806 non-null   object
#  5   cast      4806 non-null   object
#  6   crew      4806 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 429.4+ KB

# %%
genre_to_mood = {
    "Action": "Excited",
    "Adventure": "Excited",
    "Animation": "Happy",
    "Comedy": "Happy",
    "Crime": "Thrilled",
    "Documentary": "Calm",
    "Drama": "Emotional",
    "Family": "Happy",
    "Fantasy": "Curious",
    "Foreign": "Curious",
    "History": "Curious",
    "Horror": "Thrilled",
    "Music": "Happy",
    "Mystery": "Curious",
    "Romance": "Romantic",
    "ScienceFiction": "Curious",
    "TVMovie": "Happy",
    "Thriller": "Thrilled",
    "War": "Emotional",
    "Western": "Excited"
}

# %%
def mood_from_genres(genres):
    for genre in genres:
        mood = genre_to_mood.get(genre)
        if mood:
            return mood
    return "Curious"  # default if no matching genre




# Apply mood tag to each row
movies['mood_tag'] = movies['genres'].apply(mood_from_genres)

# %%
movies.sample(10)
# Out:
#                                              genres      id  \
# 3547                                        [Drama]  253253
# 3072                         [Comedy, Drama, Music]  256924
# 971                        [Comedy, Drama, Romance]   12220
# 839                         [History, Drama, Music]    8818
# 2082                     [Drama, Thriller, Mystery]   49517
# 2755                       [Fantasy, Drama, Comedy]     492
# 2558  [Adventure, Family, Fantasy, Comedy, Romance]    2493
# 3657                             [Horror, Thriller]  298312
# 630                               [Comedy, Romance]    3981
# 810     [Comedy, Music, Family, Fantasy, Animation]    6477
#
#                                                keywords  \
# 3547                                                 []
# 3072                              [rockstar, middleage]
# 971   [loveofone'slife, therapist, psychology, weddi...
# 839   [prostitute, deification, dancehallhostess, pe...
# 2082  [spy, coldwar, spying, espionage, mole, britis...
# 2755  [individual, transvestism, sexualidentity, wit...
# 2558  [swashbuckler, evilprince, referencetosocrates...
# 3657  [rapmusic, pennsylvania, brothersisterrelation...
# 630   [women, telepathy, supernaturalpowers, adverti...
# 810   [pop, popstar, recordproducer, surprise, appro...
#
#                           title  \
# 3547                    Animals
# 3072              Danny Collins
# 971             The Story of Us
# 839                       Evita
# 2082  Tinker Tailor Soldier Spy
# 2755       Being John Malkovich
# 2558         The Princess Bride
# 3657                  The Visit
# 630             What Women Want
# 810     Alvin and the Chipmunks
#
#                                                overview  \
# 3547  [ANIMALS, tells, the, story, of, Jude, and, Bo...
# 3072  [An, ageing, rock, star, decides, to, change, ...
# 971   [Ben, and, Katie, Jordan, are, a, married, cou...
# 839   [The, hit, musical, based, on, the, life, of, ...
# 2082  [Recently-retired, MI6, agent,, George, Smiley...
# 2755  [Spike, Jonze’s, debut, feature, film, is, a, ...
# 2558  [In, this, enchantingly, cracked, fairy, tale,...
# 3657  [The, terrifying, story, of, a, brother, and, ...
# 630   [Advertising, executive, Nick, Marshall, is, a...
# 810   [A, struggling, songwriter, named, Dave, Sevil...
#
#                                             cast                crew  \
# 3547     [DavidDastmalchian, KimShaw, JohnHeard]    [CollinSchiffli]
# 3072   [AlPacino, AnnetteBening, JenniferGarner]       [DanFogelman]
# 971   [BruceWillis, MichellePfeiffer, RobReiner]         [RobReiner]
# 839    [Madonna, AntonioBanderas, JonathanPryce]        [AlanParker]
# 2082          [JohnHurt, GaryOldman, KathyBurke]    [TomasAlfredson]
# 2755  [JohnCusack, CameronDiaz, CatherineKeener]        [SpikeJonze]
# 2558     [CaryElwes, RobinWright, MandyPatinkin]         [RobReiner]
# 3657   [OliviaDeJonge, EdOxenbould, KathrynHahn]  [M.NightShyamalan]
# 630          [HelenHunt, MelGibson, MarisaTomei]       [NancyMeyers]
# 810    [JasonLee, DavidCross, CameronRichardson]           [TimHill]
#
#        mood_tag
# 3547  Emotional
# 3072      Happy
# 971       Happy
# 839     Curious
# 2082  Emotional
# 2755    Curious
# 2558    Excited
# 3657   Thrilled
# 630       Happy
# 810       Happy
